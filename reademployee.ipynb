# %%
import pandas as pd

# %%
#%pip install pandas - in case library is not installed
df = pd.read_csv("employee.csv")
df

# %%
type(df)

# %%
# display first 5 rows
df.head()

# %%
# display last 5 rows
df.tail()

# %%
# display rows from index 3 to 6 # df.iloc - index location
# df.iloc[rows]
df.iloc[3:7]

# %%
# df.iloc[rows, columns]
df.iloc[3:7, 1:3]

# %%
# display datatypes of each column
df.dtypes

# %%
# more information
df.info()

# %%
# get statistics of the whole dataframe
df.describe()

# %%
df.describe(include="all")

# %%
# select workclass from tablename
# display only one column
df['workclass']

# %%
# display multiple columns
df[['workclass','education','age','gender']]

# %%
df['workclass'].value_counts()

# %%
#writing csv files
df[['workclass','education','age','gender']].to_csv("employee_subset.csv", index=False)

# %%
# distinct values in workclass column
df['workclass'].unique()

# %%
# no. of distinct values in workclass column
df['workclass'].nunique()

# %%
####################### condition based filtering #######################
#SQL:   select * from tablename where workclass = 'Private'

condition = df['workclass'] == ' Private'
df[condition]

# or

condition = df['workclass'].str.strip() == 'Private'
df[condition]

# %%
# sorting
df['educational-num'].sort_values()
